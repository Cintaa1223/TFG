# %%
import pandas as pd
import nltk
nltk.download('stopwords') #Dowload list of stopwords

import collections
from collections import defaultdict
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import re #Library used to remove certain symbols / characters from a text

##Opening Data And saving
# Load the Drive helper and mount
from google.colab import drive
# This will prompt for authorization.
drive.mount('/content/drive/')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# 1.Load CS projects' CSVs
data_path = '/content/drive/Shareddrives/TFG_Cinta_Arnau/Code/Extracted_Projects/'

# Load table from csv file (Spanish and Catalan platform)
spanishCS = pd.read_csv(data_path + 'Spanish_CS_Projects.csv')
catalanCS = pd.read_csv(data_path + 'Catalan_CS_Projects.csv')

# %%
def join_description(desc, info):
  return str(desc) + str(info)

catalanCS['Project Full Description'] = ['']*len(catalanCS)
catalanCS['Project Full Description'] = catalanCS.apply(lambda row: join_description(row['Project Description'], row['Project Info']), axis=1)
spanishCS['Project Full Description'] = ['']*len(spanishCS)
spanishCS['Project Full Description'] = spanishCS.apply(lambda row: join_description(row['Project Goal'], row['Project Description']), axis=1)

# %%
catalanCS = catalanCS.rename(columns={'Project Info': 'Project Goal'})
cols_to_keep = ['Project Name', 'Project Link', 'Project Scope', 'Project Description', 'Project Goal', 'Project Full Description', 'Citizen Science Web Name', 'Citizen Science Web Link']
catalanCS = catalanCS[cols_to_keep]
spanishCS = spanishCS[cols_to_keep]

projectsCS = pd.DataFrame()
projectsCS = pd.concat([spanishCS, catalanCS])
projectsCS = projectsCS.reset_index(drop=True)

# %%
# from google.colab import files

# # Download the resulting DataFrame df1 as a csv file
# projectsCS.to_csv('/content/CS_Projects.csv', index=False)
# files.download('/content/CS_Projects.csv')

# %%
projectsCS
# Out:
#                               Project Name  \
# 0                                LADA-UC3M
# 1                                     PAAM
# 2                          Cities at Night
# 3                               FuenAragón
# 4    Laboratorio Ciudadano de Salud Urbana
# ..                                     ...
# 362     Red de Observadores Meteorológicos
# 363                             Citi-Sense
# 364                         Saca La Lengua
# 365       Ciencia ciudadana en los barrios
# 366      Ciencia Ciudadana en las Escuelas
#
#                                           Project Link  \
# 0    https://ciencia-ciudadana.es/proyecto-cc/lada-...
# 1       https://ciencia-ciudadana.es/proyecto-cc/paam/
# 2    https://ciencia-ciudadana.es/proyecto-cc/citie...
# 3    https://ciencia-ciudadana.es/proyecto-cc/fuena...
# 4    https://ciencia-ciudadana.es/proyecto-cc/labor...
# ..                                                 ...
# 362  https://www.barcelona.cat/barcelonaciencia/es/...
# 363  https://www.barcelona.cat/barcelonaciencia/es/...
# 364  https://www.barcelona.cat/barcelonaciencia/es/...
# 365  https://www.barcelona.cat/barcelonaciencia/es/...
# 366  https://www.barcelona.cat/barcelonaciencia/es/...
#
#                                          Project Scope  \
# 0                                Cultura y Arqueología
# 1    Ciencias Sociales, Educación, Informática y Ci...
# 2    Biodiversidad, Ecología y Medioambiente, Espac...
# 3    Biodiversidad, Ciencias de la Agricultura y Ve...
# 4    Biodiversidad, Ecología y Medioambiente, Medic...
# ..                                                 ...
# 362                                                NaN
# 363                                              salud
# 364                                             salud.
# 365                                                NaN
# 366                                                NaN
#
#                                    Project Description  \
# 0    Es un laboratorio de ciencia ciudadana en el q...
# 1    El proyecto programa PAAM, tiene dos fases:\nL...
# 2    Cities at Night nace en 2014 liderada por el d...
# 3    El desarrollo del proyecto contaré con varias ...
# 4    La ciudadanía tiene un rol fundamental a la ho...
# ..                                                 ...
# 362  El Servicio Meteorológico de Cataluña creó en ...
# 363  Proyecto que pretende convertir a los ciudadan...
# 364  El proyecto quiere identificar la variedad de ...
# 365  A través de algunos de los proyectos de cienci...
# 366  La Oficina de Ciencia Ciudadana y el Consorcio...
#
#                                           Project Goal  \
# 0    Nuestro laboratorio pretende integrar a la com...
# 1    El objetivo es llegar al máximo número de pers...
# 2    A nivel mundial, la luz artificial nocturna (A...
# 3    El objetivo de FuenAragón es elaborar un mapa ...
# 4    El Laboratorio de Salud Urbana es un espacio c...
# ..                                                 ...
# 362  Estas personas aportan información meteorológi...
# 363  Con dispositivos móviles y sensores repartidos...
# 364  Los ciudadanos y ciudadanas contribuyen en dis...
# 365  En este programa, los equipamientos se suman a...
# 366  Profesorado y alumnado de centros educativos d...
#
#                               Project Full Description  \
# 0    Nuestro laboratorio pretende integrar a la com...
# 1    El objetivo es llegar al máximo número de pers...
# 2    A nivel mundial, la luz artificial nocturna (A...
# 3    El objetivo de FuenAragón es elaborar un mapa ...
# 4    El Laboratorio de Salud Urbana es un espacio c...
# ..                                                 ...
# 362  El Servicio Meteorológico de Cataluña creó en ...
# 363  Proyecto que pretende convertir a los ciudadan...
# 364  El proyecto quiere identificar la variedad de ...
# 365  A través de algunos de los proyectos de cienci...
# 366  La Oficina de Ciencia Ciudadana y el Consorcio...
#
#                            Citizen Science Web Name  \
# 0    Observatorio de la Ciencia Ciudadana en España
# 1    Observatorio de la Ciencia Ciudadana en España
# 2    Observatorio de la Ciencia Ciudadana en España
# 3    Observatorio de la Ciencia Ciudadana en España
# 4    Observatorio de la Ciencia Ciudadana en España
# ..                                              ...
# 362     Ciencia Ciudadana Ayuntamiento de Barcelona
# 363     Ciencia Ciudadana Ayuntamiento de Barcelona
# 364     Ciencia Ciudadana Ayuntamiento de Barcelona
# 365     Ciencia Ciudadana Ayuntamiento de Barcelona
# 366     Ciencia Ciudadana Ayuntamiento de Barcelona
#
#                               Citizen Science Web Link
# 0            https://ciencia-ciudadana.es/proyecto-cc/
# 1            https://ciencia-ciudadana.es/proyecto-cc/
# 2            https://ciencia-ciudadana.es/proyecto-cc/
# 3            https://ciencia-ciudadana.es/proyecto-cc/
# 4            https://ciencia-ciudadana.es/proyecto-cc/
# ..                                                 ...
# 362  https://www.barcelona.cat/barcelonaciencia/es/...
# 363  https://www.barcelona.cat/barcelonaciencia/es/...
# 364  https://www.barcelona.cat/barcelonaciencia/es/...
# 365  https://www.barcelona.cat/barcelonaciencia/es/...
# 366  https://www.barcelona.cat/barcelonaciencia/es/...
#
# [367 rows x 8 columns]

# %%
# To check all unique project scopes
scopes = []

def separate_scopes(row_scopes, scopes):
  row_scopes = str(row_scopes).replace('.', '')
  proj_scopes = row_scopes.split(', ')
  for i in proj_scopes:
    if i not in scopes:
      scopes.append(i)

projectsCS.apply(lambda row: separate_scopes(row['Project Scope'], scopes), axis=1)
scopes.remove('nan')
print(scopes)
# Out:
# ['Cultura y Arqueología', 'Ciencias Sociales', 'Educación', 'Informática y Ciencias de la Computación', 'Medicina y Salud', 'Biodiversidad', 'Ecología y Medioambiente', 'Espacio y Astronomía', 'Ciencias de la Agricultura y Veterinaria', 'Clima y Meteorología', 'Gestión de Recursos Naturales', 'Naturaleza y Aire Libre', 'Océanos', 'Agua', 'Marino y Terrestre', 'Transporte', 'Animales', 'Biogeografía', 'Ciencia de los Alimentos', 'Ciencias Químicas', 'Geografía', 'Geología y Ciencias de la Tierra', 'Insectos y Polinizadores', 'Ciencias Políticas', 'Culturas Indígenas', 'Pájaros', 'Sonido', 'Seguimiento de Especies a largo plazo', 'Física', 'Genética', 'Biología', 'social', 'ambiental', 'salud']

# %%
#This function receives a line of text as input and returns a list of the words contained in it after having removed the stopwords and non-important symbols,
#transforming to lowercase, tokenizing and stemming.

def build_terms(line):
    stemmer = PorterStemmer()
    stop_words = set(stopwords.words("spanish"))
    line = line.lower()  #Convert to lowercase
    line = line.split()  # Tokenize the text to get a list of terms
    line = [x for x in line if x not in stop_words]  # eliminate the stopwords
    line = [x for x in line if x.startswith(("@", "https://", "$", '#')) != True]  # eliminate non-important symbols
    line = [re.sub('[^a-záéíóúäëïöü]+', '', x) for x in line] # since it's in spanish we only have to worry about 'closed' accents
    line = [stemmer.stem(word) for word in line] # perform stemming
    return line

# %%
KC = input("Please enter the key competence: ")
# Out:
# Please enter the key competence: concienciación del medio ambiente

# %%
KC
# Out:
# 'concienciación del medio ambiente'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

projectsCS_clean = projectsCS.copy()

# STEP 1: Preprocess the data
projectsCS_clean['Project Full Description'].apply(build_terms)
KC = build_terms(KC)

# STEP 2: Create text embeddings
vectorizer = TfidfVectorizer()
text_embeddings = vectorizer.fit_transform(projectsCS_clean['Project Full Description'])
input_embedding = vectorizer.transform(KC)

# STEP 3: Calculate similarity (cosine similarity)
similarities = cosine_similarity(input_embedding, text_embeddings)

# Step 4: Output CS project recommendations
num_recommendations = 7  # Number of recommended projects to display
top_indices = similarities.argsort()[0][-num_recommendations:][::-1]  # Sort and get the top indices

print("Recommended Projects:")
for idx in top_indices:
    project = projectsCS.iloc[idx]
    print(f"- {project['Project Name']}: {project['Project Full Description']}")
# Out:
# Recommended Projects:
# - La colmena feliz: Sensibilizar ante uno de los mayores problemas ambientales y menos conocido: La progresiva desaparición de los insectosProyecto de sensibilización y concienciación sobre la perdida de la biodiversidad, tratando de forma transversal problemas ambientales utilizando a las abejas y polinizadores como vehículo para llegar a ellos.
#
# - Mapeado Colaborativo: nanMapeado Colaborativo es un grupo de investigación/acción para la innovación ciudadana y la canalización de la inteligencia colectiva nacida en 2016.
# Su fin es la creación de mapas colaborativos al servicio de la ciudadanía, a través de la concienciación sobre la importancia de la información geográfica en nuestro día a día y la promoción de herramientas y conocimientos para que colectivos y personas tengan la capacidad de realizar procesos de generación de información geográfica voluntaria y participativa.
#
# - Asociación Fotografía y Biodiversidad: nanLa Asociación Fotografía y Biodiversidad gestiona la plataforma on-line de trabajo colaborativo www.biodiversidadvirtual.org. En ella más de 3000 naturalistas comparten sus fotografias digitales geolocalizadas y un equipo de administradores y especialistas las organizan taxonómicamente para consulta libre de más de un millón de visitas al mes. Esta asociación deriva parte de los recursos también a actividades de divulgación , concienciación , protección y conocimiento de la biodiversidad.
#
# - SeCosta – Ciencia ciudadana para el estudio del medio marino: SeCosta es un proyecto de ciencia ciudadana que tiene como objetivo obtener medidas del medio marino al tiempo que sirve de hilo conductor para proyectos educativos.El proyecto se basa en el desarrollo de instrumentación de bajo coste y código abierto que permite medir distintos parámetros del medio marino y costero (topografía de playas, batimetrías, temperatura del agua, nivel del mar ). En el marco del proyecto se ofrecen talleres a profesores de educación secundaria para que construyan los dispositivos con los alumnos y hagan campañas de medida. Los datos luego los compila el equipo investigador y los incluye en sus bases de datos para distintos proyectos de investigación. En paralelo, los investigadores ofrecen apoyo para que desde los centros educativos monten proyectos multidisciplinares alrededor del tema escogido. Esto facilita que los alumnos trabajen temas científicos desde diversas asignaturas y que aumente la concienciación ambiental y el interés por la investigación.
#
# - RED DE PARTICIPACIÓN EN CIENCIA CIUDADANA: El Centro de Centro de Estudios Ambientales, en colaboración con la Unidad de Anillo Verde y Biodiversidad del Departamento de Medio Ambiente y Salud Pública del Ayuntamiento de Vitoria-Gasteiz, ha puesto en marcha el proyecto de «Red de Participación en Ciencia Ciudadana» para el seguimiento y conservación de la diversidad biológica que alberga nuestro Municipio. Este proyecto nace con la idea de promocionar y educar a la ciudadanía en materia de biodiversidad y debido a la necesidad actual de profundizar en el conocimiento y gestión de determinados grupos faunísticos y florísticos que habitan en nuestro entorno natural más cercano.os objetivos que abarca este proyecto van dirigidos a favorecer el desarrollo de actividades ambientales, hacer partícipe a la ciudadanía en campañas de concienciación y seguimiento del entorno natural, fomentar la colaboración ciudadana en tareas de conservación, potenciar el contacto ciudadano con el Anillo Verde y ampliar el conocimiento que tienen éstos sobre el mismo.
#
# - Proyecto 100&CIA PARA VITORIA-GASTEIZ: El objetivo principal del proyecto “100&CIA para Vitoria-Gasteiz” es la “Mejora, innovación y crecimiento de la Red de Ciencia Ciudadana de Vitoria-Gasteiz para conseguir información acerca de la biodiversidad del municipio y, por consiguiente, tomar las decisiones de gestión ambiental adecuadas para su conservación, gracias a la concienciación ciudadana”.El Centro de Centro de Estudios Ambientales, en colaboración con la Unidad de Anillo Verde y Biodiversidad del Departamento de Medio Ambiente y Salud Pública del Ayuntamiento de Vitoria-Gasteiz, pone en marcha el proyecto de «Red de Participación en Ciencia Ciudadana» en 2013 para el seguimiento y conservación de la diversidad biológica que alberga nuestro Municipio. Este proyecto nace con la idea de promocionar y educar a la ciudadanía en materia de biodiversidad y debido a la necesidad actual de profundizar en el conocimiento y gestión de determinados grupos faunísticos y florísticos que habitan en nuestro entorno natural más cercano. En la edición 2019-2020, entra en colaboración la ayuda de la Fundación Española para la Ciencia y la Tecnología - FECYT y el proyecto pasa a denominarse "100&CIA para Vitoria-Gasteiz", contando con más de 100 participantes que recogen datos a lo largo del municipio.
#
# - Paddle Surfing for Science on microplastic pollution: El proyecto “Paddle Surfing for Science” supone un cambio de paradigma en las investigaciones de microplásticos flotantes en el medio ambiente marino, permitiendo adquirir datos de la zona costera mediante tablas de paddle surf, con una resolución espacial y temporal no llevada a cabo por ninguna institución a nivel mundial hasta la fecha, y siendo la sociedad uno de los actores indispensables para este cambio.La ubicua presencia de microplásticos en nuestros océanos es un problema mundial de preocupación social creciente. Si bien muchos estudios han obtenido datos sobre la distribución de microplásticos en playas o a mar abierto, no hay información sobre microplásticos a pocos metros de la costa, una zona de transición crítica donde se produce el mayor intercambio de desechos entre el continente y el mar, y donde los grandes buques oceanográficos tienen dificultades de acceso para tomar muestras. El proyecto “Paddle Surfing for Science” va a permitir resolver esta laguna de conocimiento. Con el soporte de Surfrider Europe, diferentes colectivos de ciudadanos que dispongan de vehículos acuáticos de tracción humana obtendrán muestras científicas mediante el arrastre de una red. Las muestras se enviarán a la Universitat de Barcelona para su análisis e interpretación, y los resultados van a ser incorporados de manera continua en la página web para convertir a los colectivos en los verdaderos promotores de la investigación a la vez que aumentan su concienciación ambiental.

# %%
projectsCS.iloc[top_indices]
# Out:
#                                           Project Name  \
# 13                                    La colmena feliz
# 173                               Mapeado Colaborativo
# 256              Asociación Fotografía y Biodiversidad
# 20   SeCosta – Ciencia ciudadana para el estudio de...
# 327          RED DE PARTICIPACIÓN EN CIENCIA CIUDADANA
# 98               Proyecto 100&CIA PARA VITORIA-GASTEIZ
# 90   Paddle Surfing for Science on microplastic pol...
#
#                                           Project Link  \
# 13   https://ciencia-ciudadana.es/proyecto-cc/la-co...
# 173  https://ciencia-ciudadana.es/proyecto-cc/mapea...
# 256  https://ciencia-ciudadana.es/proyecto-cc/asoci...
# 20   https://ciencia-ciudadana.es/proyecto-cc/secos...
# 327  https://ciencia-ciudadana.es/proyecto-cc/red-d...
# 98   https://ciencia-ciudadana.es/proyecto-cc/proye...
# 90   https://ciencia-ciudadana.es/proyecto-cc/paddl...
#
#                                          Project Scope  \
# 13   Biodiversidad, Ecología y Medioambiente, Educa...
# 173                                  Ciencias Sociales
# 256                   Biodiversidad, Biología, Pájaros
# 20   Clima y Meteorología, Física, Océanos, Agua, M...
# 327  Animales, Biodiversidad, Biología, Ecología y ...
# 98   Animales, Biodiversidad, Biología, Ciencias de...
# 90   Ecología y Medioambiente, Geología y Ciencias ...
#
#                                    Project Description  \
# 13   Proyecto de sensibilización y concienciación s...
# 173  Mapeado Colaborativo es un grupo de investigac...
# 256  La Asociación Fotografía y Biodiversidad gesti...
# 20   El proyecto se basa en el desarrollo de instru...
# 327  os objetivos que abarca este proyecto van diri...
# 98   El Centro de Centro de Estudios Ambientales, e...
# 90   La ubicua presencia de microplásticos en nuest...
#
#                                           Project Goal  \
# 13   Sensibilizar ante uno de los mayores problemas...
# 173                                                NaN
# 256                                                NaN
# 20   SeCosta es un proyecto de ciencia ciudadana qu...
# 327  El Centro de Centro de Estudios Ambientales, e...
# 98   El objetivo principal del proyecto “100&CIA pa...
# 90   El proyecto “Paddle Surfing for Science” supon...
#
#                               Project Full Description  \
# 13   Sensibilizar ante uno de los mayores problemas...
# 173  nanMapeado Colaborativo es un grupo de investi...
# 256  nanLa Asociación Fotografía y Biodiversidad ge...
# 20   SeCosta es un proyecto de ciencia ciudadana qu...
# 327  El Centro de Centro de Estudios Ambientales, e...
# 98   El objetivo principal del proyecto “100&CIA pa...
# 90   El proyecto “Paddle Surfing for Science” supon...
#
#                            Citizen Science Web Name  \
# 13   Observatorio de la Ciencia Ciudadana en España
# 173  Observatorio de la Ciencia Ciudadana en España
# 256  Observatorio de la Ciencia Ciudadana en España
# 20   Observatorio de la Ciencia Ciudadana en España
# 327  Observatorio de la Ciencia Ciudadana en España
# 98   Observatorio de la Ciencia Ciudadana en España
# 90   Observatorio de la Ciencia Ciudadana en España
#
#                       Citizen Science Web Link
# 13   https://ciencia-ciudadana.es/proyecto-cc/
# 173  https://ciencia-ciudadana.es/proyecto-cc/
# 256  https://ciencia-ciudadana.es/proyecto-cc/
# 20   https://ciencia-ciudadana.es/proyecto-cc/
# 327  https://ciencia-ciudadana.es/proyecto-cc/
# 98   https://ciencia-ciudadana.es/proyecto-cc/
# 90   https://ciencia-ciudadana.es/proyecto-cc/

# %%
similarities[0].sort()
similarities[0][-num_recommendations:][::-1]
# Out:
# array([0.17050974, 0.14104352, 0.13960967, 0.09059667, 0.09054423,
#        0.0681286 , 0.06247686])

# %%
top_idx_desc = []
for idx in top_indices:
  top_idx_desc.append(', '.join(build_terms(projectsCS_clean['Project Full Description'].iloc[idx])))

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(max_words=150, background_color="white").generate(', '.join(top_idx_desc))
plt.figure(figsize = (10,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
