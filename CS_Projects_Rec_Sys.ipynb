# %%
import pandas as pd
import nltk
nltk.download('stopwords') #Dowload list of stopwords

import collections
from collections import defaultdict
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import re #Library used to remove certain symbols / characters from a text

##Opening Data And saving
# Load the Drive helper and mount
from google.colab import drive
# This will prompt for authorization.
drive.mount('/content/drive/')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# 1.Load CS projects' CSVs
data_path = '/content/drive/Shareddrives/TFG_Cinta_Arnau/Code/Extracted_Projects/'

# Load table from csv file (Spanish and Catalan platform)
spanishCS = pd.read_csv(data_path + 'Spanish_CS_Projects.csv')
catalanCS = pd.read_csv(data_path + 'Catalan_CS_Projects.csv')

# %%
def join_description(desc, info):
  return str(desc) + str(info)

catalanCS['Project Full Description'] = ['']*len(catalanCS)
catalanCS['Project Full Description'] = catalanCS.apply(lambda row: join_description(row['Project Description'], row['Project Info']), axis=1)
spanishCS['Project Full Description'] = ['']*len(spanishCS)
spanishCS['Project Full Description'] = spanishCS.apply(lambda row: join_description(row['Project Goal'], row['Project Description']), axis=1)

# %%
catalanCS = catalanCS.rename(columns={'Project Info': 'Project Goal'})
cols_to_keep = ['Project Name', 'Project Link', 'Project Scope', 'Project Description', 'Project Goal', 'Project Full Description', 'Citizen Science Web Name', 'Citizen Science Web Link']
catalanCS = catalanCS[cols_to_keep]
spanishCS = spanishCS[cols_to_keep]

projectsCS = pd.DataFrame()
projectsCS = pd.concat([spanishCS, catalanCS])
projectsCS = projectsCS.reset_index(drop=True)

# %%
projectsCS
# Out:
#                               Project Name  \
# 0                                LADA-UC3M
# 1                                     PAAM
# 2                          Cities at Night
# 3                               FuenAragón
# 4    Laboratorio Ciudadano de Salud Urbana
# ..                                     ...
# 362     Red de Observadores Meteorológicos
# 363                             Citi-Sense
# 364                         Saca La Lengua
# 365       Ciencia ciudadana en los barrios
# 366      Ciencia Ciudadana en las Escuelas
#
#                                           Project Link  \
# 0    https://ciencia-ciudadana.es/proyecto-cc/lada-...
# 1       https://ciencia-ciudadana.es/proyecto-cc/paam/
# 2    https://ciencia-ciudadana.es/proyecto-cc/citie...
# 3    https://ciencia-ciudadana.es/proyecto-cc/fuena...
# 4    https://ciencia-ciudadana.es/proyecto-cc/labor...
# ..                                                 ...
# 362  https://www.barcelona.cat/barcelonaciencia/es/...
# 363  https://www.barcelona.cat/barcelonaciencia/es/...
# 364  https://www.barcelona.cat/barcelonaciencia/es/...
# 365  https://www.barcelona.cat/barcelonaciencia/es/...
# 366  https://www.barcelona.cat/barcelonaciencia/es/...
#
#                                          Project Scope  \
# 0                                Cultura y Arqueología
# 1    Ciencias Sociales, Educación, Informática y Ci...
# 2    Biodiversidad, Ecología y Medioambiente, Espac...
# 3    Biodiversidad, Ciencias de la Agricultura y Ve...
# 4    Biodiversidad, Ecología y Medioambiente, Medic...
# ..                                                 ...
# 362                                                NaN
# 363                                              salud
# 364                                             salud.
# 365                                                NaN
# 366                                                NaN
#
#                                    Project Description  \
# 0    Es un laboratorio de ciencia ciudadana en el q...
# 1    El proyecto programa PAAM, tiene dos fases:\nL...
# 2    Cities at Night nace en 2014 liderada por el d...
# 3    El desarrollo del proyecto contaré con varias ...
# 4    La ciudadanía tiene un rol fundamental a la ho...
# ..                                                 ...
# 362  El Servicio Meteorológico de Cataluña creó en ...
# 363  Proyecto que pretende convertir a los ciudadan...
# 364  El proyecto quiere identificar la variedad de ...
# 365  A través de algunos de los proyectos de cienci...
# 366  La Oficina de Ciencia Ciudadana y el Consorcio...
#
#                                           Project Goal  \
# 0    Nuestro laboratorio pretende integrar a la com...
# 1    El objetivo es llegar al máximo número de pers...
# 2    A nivel mundial, la luz artificial nocturna (A...
# 3    El objetivo de FuenAragón es elaborar un mapa ...
# 4    El Laboratorio de Salud Urbana es un espacio c...
# ..                                                 ...
# 362  Estas personas aportan información meteorológi...
# 363  Con dispositivos móviles y sensores repartidos...
# 364  Los ciudadanos y ciudadanas contribuyen en dis...
# 365  En este programa, los equipamientos se suman a...
# 366  Profesorado y alumnado de centros educativos d...
#
#                               Project Full Description  \
# 0    Nuestro laboratorio pretende integrar a la com...
# 1    El objetivo es llegar al máximo número de pers...
# 2    A nivel mundial, la luz artificial nocturna (A...
# 3    El objetivo de FuenAragón es elaborar un mapa ...
# 4    El Laboratorio de Salud Urbana es un espacio c...
# ..                                                 ...
# 362  El Servicio Meteorológico de Cataluña creó en ...
# 363  Proyecto que pretende convertir a los ciudadan...
# 364  El proyecto quiere identificar la variedad de ...
# 365  A través de algunos de los proyectos de cienci...
# 366  La Oficina de Ciencia Ciudadana y el Consorcio...
#
#                            Citizen Science Web Name  \
# 0    Observatorio de la Ciencia Ciudadana en España
# 1    Observatorio de la Ciencia Ciudadana en España
# 2    Observatorio de la Ciencia Ciudadana en España
# 3    Observatorio de la Ciencia Ciudadana en España
# 4    Observatorio de la Ciencia Ciudadana en España
# ..                                              ...
# 362     Ciencia Ciudadana Ayuntamiento de Barcelona
# 363     Ciencia Ciudadana Ayuntamiento de Barcelona
# 364     Ciencia Ciudadana Ayuntamiento de Barcelona
# 365     Ciencia Ciudadana Ayuntamiento de Barcelona
# 366     Ciencia Ciudadana Ayuntamiento de Barcelona
#
#                               Citizen Science Web Link
# 0            https://ciencia-ciudadana.es/proyecto-cc/
# 1            https://ciencia-ciudadana.es/proyecto-cc/
# 2            https://ciencia-ciudadana.es/proyecto-cc/
# 3            https://ciencia-ciudadana.es/proyecto-cc/
# 4            https://ciencia-ciudadana.es/proyecto-cc/
# ..                                                 ...
# 362  https://www.barcelona.cat/barcelonaciencia/es/...
# 363  https://www.barcelona.cat/barcelonaciencia/es/...
# 364  https://www.barcelona.cat/barcelonaciencia/es/...
# 365  https://www.barcelona.cat/barcelonaciencia/es/...
# 366  https://www.barcelona.cat/barcelonaciencia/es/...
#
# [367 rows x 8 columns]

# %%
# To check all unique project scopes
scopes = []

def separate_scopes(row_scopes, scopes):
  row_scopes = str(row_scopes).replace('.', '')
  proj_scopes = row_scopes.split(', ')
  for i in proj_scopes:
    if i not in scopes:
      scopes.append(i)

projectsCS.apply(lambda row: separate_scopes(row['Project Scope'], scopes), axis=1)
scopes.remove('nan')
print(scopes)
# Out:
# ['Cultura y Arqueología', 'Ciencias Sociales', 'Educación', 'Informática y Ciencias de la Computación', 'Medicina y Salud', 'Biodiversidad', 'Ecología y Medioambiente', 'Espacio y Astronomía', 'Ciencias de la Agricultura y Veterinaria', 'Clima y Meteorología', 'Gestión de Recursos Naturales', 'Naturaleza y Aire Libre', 'Océanos', 'Agua', 'Marino y Terrestre', 'Transporte', 'Animales', 'Biogeografía', 'Ciencia de los Alimentos', 'Ciencias Químicas', 'Geografía', 'Geología y Ciencias de la Tierra', 'Insectos y Polinizadores', 'Ciencias Políticas', 'Culturas Indígenas', 'Pájaros', 'Sonido', 'Seguimiento de Especies a largo plazo', 'Física', 'Genética', 'Biología', 'social', 'ambiental', 'salud']

# %%
#This function receives a line of text as input and returns a list of the words contained in it after having removed the stopwords and non-important symbols, 
#transforming to lowercase, tokenizing and stemming.

def build_terms(line): 
    stemmer = PorterStemmer()
    stop_words = set(stopwords.words("spanish"))
    line = line.lower()  #Convert to lowercase
    line = line.split()  # Tokenize the text to get a list of terms
    line = [x for x in line if x not in stop_words]  # eliminate the stopwords
    line = [x for x in line if x.startswith(("@", "https://", "$", '#')) != True]  # eliminate non-important symbols
    line = [re.sub('[^a-záéíóúäëïöü]+', '', x) for x in line] # since it's in spanish we only have to worry about 'closed' accents
    line = [stemmer.stem(word) for word in line] # perform stemming
    return line

# %%
KC = input("Please enter the key competence: ")
# Out:
# Please enter the key competence: igualdad de género

# %%
KC
# Out:
# 'igualdad de género'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

projectsCS_clean = projectsCS.copy()

# STEP 1: Preprocess the data
projectsCS_clean['Project Full Description'].apply(build_terms)

# STEP 2: Create text embeddings
vectorizer = TfidfVectorizer()
text_embeddings = vectorizer.fit_transform(projectsCS_clean['Project Full Description'])

# STEP 3: Preprocess key competence
KC = build_terms(KC)

# STEP 4: Calculate similarity (cosine similarity)
input_embedding = vectorizer.transform(KC)
similarities = cosine_similarity(input_embedding, text_embeddings)

# Step 5: Output CS project recommendations
num_recommendations = 5  # Number of recommended projects to display
top_indices = similarities.argsort()[0][-num_recommendations:][::-1]  # Sort and get the top indices

print("Recommended Projects:")
for idx in top_indices:
    project = projectsCS.iloc[idx]
    print(f"- {project['Project Name']}: {project['Project Full Description']}")
# Out:
# Recommended Projects:
# - CoAct (Co-designing Citizen Social Science for Collective Action)/ Co-diseñando la Ciencia Ciudadana Social para la Acción Colectiva: CoAct es un proyecto financiado por el programa Horizonte 2020 de la Unión Europea. CoAct propone una nueva comprensión de la Ciencia Ciudadana Social como investigación participativa co-diseñada e impulsada directamente por grupos de ciudadanos que comparten una preocupación social, en la que se convierten en co-investigadores en procesos comúnmente dominados por investigadores académicos. CoAct tiene como objetivo reunir y desarrollar métodos para dar a los grupos de ciudadanos un "asiento en la mesa" en igualdad de condiciones mediante la participación activa en la investigación, desde el diseño hasta la interpretación de los resultados y su transformación en acciones concretas.Trabajaremos simultáneamente con organizaciones de la sociedad civil en una amplia escala geográfica (España, Austria, Alemania, países de Europa del Este, Paneuropeo y Argentina), abordando cuatro temas sociales: Atención en Salud Mental, Empleo Juvenil, Justicia Ambiental e Igualdad de Género.
#
# - Universidad de los Pacientes: nanLa Universidad de los Pacientes es una universidad específica y monográfica dedicada a pacientes, familiares, cuidadores, voluntarios y ciudadanos en general, interesados en temas de salud y sanidad.
# La Universidad de los Pacientes quiere contribuir en la promoción de la igualdad de oportunidades en la educación y el acceso a una asistencia de calidad por parte de los pacientes y los usuarios de los servicios de salud.
# Esta institución tiene como objetivo general participar en la promoción de la modernización y la mejora de la calidad de la atención sanitaria mediante el desarrollo de actividades de información, formación e investigación.
#
# - Feminicidio.net: nanFeminicidio.net es un proyecto sin fines de lucro de la asociación Otro Tiempo. Por un lado, es un portal de noticias con perspectiva de género que se nutre de la elaboración propia de reportajes, entrevistas, artículos, investigaciones especiales e informes sobre feminicidio y violencia de género por países de Iberoamérica. También publicamos noticias de otros medios de comunicación on line. Por otro lado, hemos creado la Base de Datos Feminicidio en Iberoamérica, destinada a documentar los asesinatos de mujeres por razón de género de 21 países, tanto casos particulares y paradigmáticos como recuentos globales por Estados. Documentación constituye la tercera columna vertebral de la estructura de contenidos de Feminicidio.net. En dicha sección difundimos artículos, ensayos, informes, estudios, guías, manuales, normativa por países, recomendaciones, resoluciones y sanciones a los Estados sobre los siguientes temas: feminicidio-femicidio, violencia de género, tráfico de personas con fines de explotación sexual e igualdad.
#
# - CoActuamos para la Salud Mental: CoActuamos para la Salud Mental quiere reforzar las redes de apoyo social en salud mental a través de una investigación participativa y participada, dentro de la llamada ciencia ciudadana social.Dentro del marco de la ciencia ciudadana, la propuesta de investigación con la cooperación ciudadana se fundamenta en el mutuo reconocimiento de la diversidad y complementariedad de los diversos agentes del ámbito de la salud mental y en su potencial de trabajo colaborativo en plan de igualdad. El proceso busca hacer visible la amplia comunidad de personas e instituciones que participan del ámbito de la Salud Mental (Entorno de Conocimiento) y situar en su centro a las personas con experiencia propia en salud mental y sus entornos familiares (Co-investigadoras). El Entorno de Conocimiento, con su bagaje, enmarca, hace seguimiento y ayuda en la investigación de las personas co-investigadoras. Organizadas en varios grupos cooperativos, estas personas se convierten en co-investigadoras, siendo el centro y el motor de la investigación, al tiempo que co-actoras en las redes de apoyo social. El resultado de la interacción y el trabajo de los grupos cooperativos y la ciudadanía permitirá construir una conversación digital (chatbot) que aportará el conocimiento necesario para legitimar las propuestas que las personas con experiencia propia sitúan en el centro de la investigación desde el momento inicial.
#
# - Diviértete con la Estadística: Fomentar el aprendizaje y uso de la Estadística como forma de medir de forma objetiva el mundo que nos rodea.nan

# %%
projectsCS.iloc[top_indices]
# Out:
#                                           Project Name  \
# 80   CoAct (Co-designing Citizen Social Science for...
# 170                       Universidad de los Pacientes
# 245                                    Feminicidio.net
# 79                     CoActuamos para la Salud Mental
# 116                      Diviértete con la Estadística
#
#                                           Project Link  \
# 80   https://ciencia-ciudadana.es/proyecto-cc/coact...
# 170  https://ciencia-ciudadana.es/proyecto-cc/unive...
# 245  https://ciencia-ciudadana.es/proyecto-cc/femin...
# 79   https://ciencia-ciudadana.es/proyecto-cc/coact...
# 116  https://ciencia-ciudadana.es/proyecto-cc/divie...
#
#                                          Project Scope  \
# 80   Ciencias Sociales, Informática y Ciencias de l...
# 170                         Biología, Medicina y Salud
# 245  Ciencias Sociales, Informática y Ciencias de l...
# 79   Ciencias Sociales, Física, Informática y Cienc...
# 116  Ecología y Medioambiente, Informática y Cienci...
#
#                                    Project Description  \
# 80   Trabajaremos simultáneamente con organizacione...
# 170  La Universidad de los Pacientes es una univers...
# 245  Feminicidio.net es un proyecto sin fines de lu...
# 79   Dentro del marco de la ciencia ciudadana, la p...
# 116                                                NaN
#
#                                           Project Goal  \
# 80   CoAct es un proyecto financiado por el program...
# 170                                                NaN
# 245                                                NaN
# 79   CoActuamos para la Salud Mental quiere reforza...
# 116  Fomentar el aprendizaje y uso de la Estadístic...
#
#                               Project Full Description  \
# 80   CoAct es un proyecto financiado por el program...
# 170  nanLa Universidad de los Pacientes es una univ...
# 245  nanFeminicidio.net es un proyecto sin fines de...
# 79   CoActuamos para la Salud Mental quiere reforza...
# 116  Fomentar el aprendizaje y uso de la Estadístic...
#
#                            Citizen Science Web Name  \
# 80   Observatorio de la Ciencia Ciudadana en España
# 170  Observatorio de la Ciencia Ciudadana en España
# 245  Observatorio de la Ciencia Ciudadana en España
# 79   Observatorio de la Ciencia Ciudadana en España
# 116  Observatorio de la Ciencia Ciudadana en España
#
#                       Citizen Science Web Link
# 80   https://ciencia-ciudadana.es/proyecto-cc/
# 170  https://ciencia-ciudadana.es/proyecto-cc/
# 245  https://ciencia-ciudadana.es/proyecto-cc/
# 79   https://ciencia-ciudadana.es/proyecto-cc/
# 116  https://ciencia-ciudadana.es/proyecto-cc/

# %%
top_idx_desc = []
for idx in top_indices:
  top_idx_desc.append(', '.join(build_terms(projectsCS_clean['Project Full Description'].iloc[idx])))

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

wordcloud = WordCloud(max_words=150, background_color="white").generate(', '.join(top_idx_desc))
plt.figure(figsize = (10,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
