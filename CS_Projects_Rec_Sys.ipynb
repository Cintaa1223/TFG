# %%
import pandas as pd
import nltk
nltk.download('stopwords') #Dowload list of stopwords

import collections
from collections import defaultdict
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import re #Library used to remove certain symbols / characters from a text

##Opening Data And saving
# Load the Drive helper and mount
from google.colab import drive
# This will prompt for authorization.
drive.mount('/content/drive/')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Mounted at /content/drive/

# %%
# 1.Load CS projects' CSVs
data_path = '/content/drive/Shareddrives/TFG_Cinta_Arnau/Code/Extracted_Projects/'

# Load table from csv file (Spanish and Catalan platform)
spanishCS = pd.read_csv(data_path + 'Spanish_CS_Projects.csv')
catalanCS = pd.read_csv(data_path + 'Catalan_CS_Projects.csv')

# %%
def join_description(desc, info):
  return str(desc) + str(info)

catalanCS['Project Full Description'] = ['']*len(catalanCS)
catalanCS['Project Full Description'] = catalanCS.apply(lambda row: join_description(row['Project Description'], row['Project Info']), axis=1)
spanishCS['Project Full Description'] = ['']*len(spanishCS)
spanishCS['Project Full Description'] = spanishCS.apply(lambda row: join_description(row['Project Goal'], row['Project Description']), axis=1)

# %%
catalanCS = catalanCS.rename(columns={'Project Info': 'Project Goal'})
cols_to_keep = ['Project Name', 'Project Link', 'Project Scope', 'Project Description', 'Project Goal', 'Project Full Description', 'Citizen Science Web Name', 'Citizen Science Web Link']
catalanCS = catalanCS[cols_to_keep]
spanishCS = spanishCS[cols_to_keep]

projectsCS = pd.DataFrame()
projectsCS = pd.concat([spanishCS, catalanCS])
projectsCS = projectsCS.reset_index(drop=True)

# %%
projectsCS
# Out:
#                               Project Name  \
# 0                                LADA-UC3M
# 1                                     PAAM
# 2                          Cities at Night
# 3                               FuenAragón
# 4    Laboratorio Ciudadano de Salud Urbana
# ..                                     ...
# 362     Red de Observadores Meteorológicos
# 363                             Citi-Sense
# 364                         Saca La Lengua
# 365       Ciencia ciudadana en los barrios
# 366      Ciencia Ciudadana en las Escuelas
#
#                                           Project Link  \
# 0    https://ciencia-ciudadana.es/proyecto-cc/lada-...
# 1       https://ciencia-ciudadana.es/proyecto-cc/paam/
# 2    https://ciencia-ciudadana.es/proyecto-cc/citie...
# 3    https://ciencia-ciudadana.es/proyecto-cc/fuena...
# 4    https://ciencia-ciudadana.es/proyecto-cc/labor...
# ..                                                 ...
# 362  https://www.barcelona.cat/barcelonaciencia/es/...
# 363  https://www.barcelona.cat/barcelonaciencia/es/...
# 364  https://www.barcelona.cat/barcelonaciencia/es/...
# 365  https://www.barcelona.cat/barcelonaciencia/es/...
# 366  https://www.barcelona.cat/barcelonaciencia/es/...
#
#                                          Project Scope  \
# 0                                Cultura y Arqueología
# 1    Ciencias Sociales, Educación, Informática y Ci...
# 2    Biodiversidad, Ecología y Medioambiente, Espac...
# 3    Biodiversidad, Ciencias de la Agricultura y Ve...
# 4    Biodiversidad, Ecología y Medioambiente, Medic...
# ..                                                 ...
# 362                                                NaN
# 363                                              salud
# 364                                             salud.
# 365                                                NaN
# 366                                                NaN
#
#                                    Project Description  \
# 0    Es un laboratorio de ciencia ciudadana en el q...
# 1    El proyecto programa PAAM, tiene dos fases:\nL...
# 2    Cities at Night nace en 2014 liderada por el d...
# 3    El desarrollo del proyecto contaré con varias ...
# 4    La ciudadanía tiene un rol fundamental a la ho...
# ..                                                 ...
# 362  El Servicio Meteorológico de Cataluña creó en ...
# 363  Proyecto que pretende convertir a los ciudadan...
# 364  El proyecto quiere identificar la variedad de ...
# 365  A través de algunos de los proyectos de cienci...
# 366  La Oficina de Ciencia Ciudadana y el Consorcio...
#
#                                           Project Goal  \
# 0    Nuestro laboratorio pretende integrar a la com...
# 1    El objetivo es llegar al máximo número de pers...
# 2    A nivel mundial, la luz artificial nocturna (A...
# 3    El objetivo de FuenAragón es elaborar un mapa ...
# 4    El Laboratorio de Salud Urbana es un espacio c...
# ..                                                 ...
# 362  Estas personas aportan información meteorológi...
# 363  Con dispositivos móviles y sensores repartidos...
# 364  Los ciudadanos y ciudadanas contribuyen en dis...
# 365  En este programa, los equipamientos se suman a...
# 366  Profesorado y alumnado de centros educativos d...
#
#                               Project Full Description  \
# 0    Nuestro laboratorio pretende integrar a la com...
# 1    El objetivo es llegar al máximo número de pers...
# 2    A nivel mundial, la luz artificial nocturna (A...
# 3    El objetivo de FuenAragón es elaborar un mapa ...
# 4    El Laboratorio de Salud Urbana es un espacio c...
# ..                                                 ...
# 362  El Servicio Meteorológico de Cataluña creó en ...
# 363  Proyecto que pretende convertir a los ciudadan...
# 364  El proyecto quiere identificar la variedad de ...
# 365  A través de algunos de los proyectos de cienci...
# 366  La Oficina de Ciencia Ciudadana y el Consorcio...
#
#                            Citizen Science Web Name  \
# 0    Observatorio de la Ciencia Ciudadana en España
# 1    Observatorio de la Ciencia Ciudadana en España
# 2    Observatorio de la Ciencia Ciudadana en España
# 3    Observatorio de la Ciencia Ciudadana en España
# 4    Observatorio de la Ciencia Ciudadana en España
# ..                                              ...
# 362     Ciencia Ciudadana Ayuntamiento de Barcelona
# 363     Ciencia Ciudadana Ayuntamiento de Barcelona
# 364     Ciencia Ciudadana Ayuntamiento de Barcelona
# 365     Ciencia Ciudadana Ayuntamiento de Barcelona
# 366     Ciencia Ciudadana Ayuntamiento de Barcelona
#
#                               Citizen Science Web Link
# 0            https://ciencia-ciudadana.es/proyecto-cc/
# 1            https://ciencia-ciudadana.es/proyecto-cc/
# 2            https://ciencia-ciudadana.es/proyecto-cc/
# 3            https://ciencia-ciudadana.es/proyecto-cc/
# 4            https://ciencia-ciudadana.es/proyecto-cc/
# ..                                                 ...
# 362  https://www.barcelona.cat/barcelonaciencia/es/...
# 363  https://www.barcelona.cat/barcelonaciencia/es/...
# 364  https://www.barcelona.cat/barcelonaciencia/es/...
# 365  https://www.barcelona.cat/barcelonaciencia/es/...
# 366  https://www.barcelona.cat/barcelonaciencia/es/...
#
# [367 rows x 8 columns]

# %%
# To check all unique project scopes in the Spanish platform
scopes = []

def separate_scopes(row_scopes, scopes):
  row_scopes = str(row_scopes).replace('.', '')
  proj_scopes = row_scopes.split(', ')
  for i in proj_scopes:
    if i not in scopes:
      scopes.append(i)

projectsCS.apply(lambda row: separate_scopes(row['Project Scope'], scopes), axis=1)
scopes.remove('nan')
print(scopes)
# Out:
# ['Cultura y Arqueología', 'Ciencias Sociales', 'Educación', 'Informática y Ciencias de la Computación', 'Medicina y Salud', 'Biodiversidad', 'Ecología y Medioambiente', 'Espacio y Astronomía', 'Ciencias de la Agricultura y Veterinaria', 'Clima y Meteorología', 'Gestión de Recursos Naturales', 'Naturaleza y Aire Libre', 'Océanos', 'Agua', 'Marino y Terrestre', 'Transporte', 'Animales', 'Biogeografía', 'Ciencia de los Alimentos', 'Ciencias Químicas', 'Geografía', 'Geología y Ciencias de la Tierra', 'Insectos y Polinizadores', 'Ciencias Políticas', 'Culturas Indígenas', 'Pájaros', 'Sonido', 'Seguimiento de Especies a largo plazo', 'Física', 'Genética', 'Biología', 'social', 'ambiental', 'salud']

# %%
#This function receives a line of text as input and returns a list of the words contained in it after having removed the stopwords and non-important symbols, 
#transforming to lowercase, tokenizing and stemming.

def build_terms(line): 
    stemmer = PorterStemmer()
    stop_words = set(stopwords.words("spanish"))
    line = line.lower()  #Convert to lowercase
    line = line.split()  # Tokenize the text to get a list of terms
    line = [x for x in line if x not in stop_words]  # eliminate the stopwords
    line = [x for x in line if x.startswith(("@", "https://", "$", '#')) != True]  # eliminate non-important symbols
    line = [re.sub('[^a-záéíóúäëïöü]+', '', x) for x in line] # since it's in spanish we only have to worry about 'closed' accents
    line = [stemmer.stem(word) for word in line] # perform stemming
    return line

# %%
KC = input("Please enter the key competence: ")
# Out:
# Please enter the key competence: vida saludable

# %%
KC
# Out:
# 'vida saludable'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

projectsCS_clean = projectsCS.copy()

# STEP 1: Preprocess the data
projectsCS_clean['Project Full Description'].apply(build_terms)

# STEP 2: Create text embeddings
vectorizer = TfidfVectorizer()
text_embeddings = vectorizer.fit_transform(projectsCS_clean['Project Full Description'])

# STEP 3: Preprocess key competence
KC = build_terms(KC)

# STEP 4: Calculate similarity (cosine similarity)
input_embedding = vectorizer.transform(KC)
similarities = cosine_similarity(input_embedding, text_embeddings)

# Step 5: Output CS project recommendations
num_recommendations = 5  # Number of recommended projects to display
top_indices = similarities.argsort()[0][-num_recommendations:][::-1]  # Sort and get the top indices

print("Recommended Projects:")
for idx in top_indices:
    project = projectsCS.iloc[idx]
    print(f"- {project['Project Name']}: {project['Project Full Description']}")
# Out:
# Recommended Projects:
# - GavaLab: Thinkers Factory  basada en "el concepto de garage"  donde las Ideas y la Innovación forman parte de la vida de las personas, especialmente alumnos de Secundaria.nan
# - Banco de Imágenes del Mundo rural: Preservar, conocer y difundir el patrimonio rural de Burgos (y por extensión el de las provincias limítrofes)¿Qué es el Banco de imágenes del mundo rural?
# El Banco de imágenes del mundo rural es un proyecto colaborativo que busca recopilar fotografías de la vida de nuestros pueblos. El objetivo es conseguir un material gráfico y descriptivo de manifestaciones y prácticas como labores, oficios, fiestas, costumbres, reuniones, romerías, tradiciones, aperos, razas ganaderas, etc. Un patrimonio de singular importancia. Importan las imágenes, lo que contienen y lo que representan, el saber y personas que hay detrás de ellas... Apoyados en la colaboración de aquellos particulares que quieran compartir sus fotografías, el proyecto organizará un completo catálogo mediante la clasificación y descripción de cada imagen (partiendo de la información aportada por los titulares).
# ¿Para qué el Banco de imágenes del mundo rural?
# El Banco de imágenes del mundo rural servirá como testimonio colectivo de las formas de vida tradicionales de la provincia de Burgos, también como material de consulta y estudio para curiosos e investigadores. Dada la gran transformación sufrida en nuestro sistema de vida reciente, con la recopilación de esta información ayudaremos a evitar las rupturas de conocimiento que se producen entre las últimas generaciones, desconocedoras de prácticas que han estado vigentes hasta hace unos pocos años. Es, también, un proyecto sentimental sobre nuestros pueblos, sobre nuestras gentes y vidas. O lo que es lo mismo, una buena herramienta para paliar o reducir la cada vez más creciente desconexión entre el mundo rural y el urbano, pero también entre el pasado y el presente.
# ¿Qué buscamos con esta iniciativa de un Banco de imágenes del mundo rural?
# Que compartan con nosotros sus fotos, independientemente de su calidad, pues lo que nos interesa son los momentos de vida cotidiana, de reunión, de trabajo, de celebración… Al ser este un proyecto digital, no necesitamos los originales, nos vale con que las escaneen (o, incluso, que nos envíen una foto de la fotografía hecha con cierto mimo). Nos interesan las fotos y las explicaciones de estas, lo que sucede, lo que cuentan, lo que hacen, quiénes son…).
# Preservar, conocer y divulgar. El Banco de imágenes del mundo rural es un proyecto de ciencia ciudadana promovido por la Cátedra de Etnografía y Estudios del Medio Rural (CEEMR), de la Universidad de Burgos, con el apoyo de la Diputación de Burgos. Precisamos de la colaboración de cualquier ciudadano/a que, amante de su pueblo y tradiciones, nos envíe retazos de la vida de cada localidad.
#
# - Cicada.cat: Ampliar el conocimiento sobre las cigarras (Cicadidae) en Cataluña y hacerlo público y disponible en una web. Promover la participación de la ciudadanía en adquirir información sobre el grupo.Cicada.cat avanza en el conocimiento y divulgación de la biología de las cigarras (Cicadidae), los insectos más ruidosos del verano. Contiene la descripción de las especies de cigarras de Cataluña, su distribución, ciclo de vida, ecología y comportamiento, así como información para identificarlas.
# Sabías que las cigarras pasan la mayor parte de su larga vida bajo tierra? • Que sólo cantan los machos? • Que las hembras pueden inyectar más de 100 huevos dentro de una planta? • Que se encuentran en todo el mundo, en lugares como Canadá, China, Madagascar, Vietnam o Nueva Zelanda?
#
# - «CIUDADES que CUIDAN»: Una ciudad que cuida ha de ser un referente donde sus ciudadanos puedan envejecer saludablemente y participar cocreando de forma activa, las condiciones, servicios y estructuras, en la mejora del bien común. Debe permitir integrar los valores y los procesos para abordar el final de la vida en paz y dignidad, enmarcada en un entorno de innovación y conocimiento basado en la creatividad y alta tecnología, y comprometida con la promoción y protección de la salud de todos sus ciudadanos. El bienestar para todos, en comunidades inclusivas, seguras, resilientes y sostenibles.Observatorio, para generar y facilitar información sensible y útil, con el fin de identificar, comparar y entender mejor que homologa a las Ciudades que Cuidan, poniendo énfasis en la soledad no deseada en el final de la vida y la muerte en soledad.
# Espacio de reflexión e intercambio de conocimiento para disponer de un área de contraste y reflexión ordenada de los principales ámbitos de actuación y elementos, que permita profundizar y aportar nuevo conocimiento sobre las Ciudades que Cuidan.
# Protocolo de actuación, de las mejores prácticas, que ha de permitir a la Fundación Mémora ofrecer a las administraciones una guía básica para desarrollar su proyecto de Ciudades que Cuidan.
# Proyecto de soporte tecnológico para la monitorización de las personas en alto riesgo de muerte en soledad con el fin de poder detectarla y prevenirla.
#
# - Centro de Investigación y Tecnología Agroalimentaria de Aragón -CITA-: El CITA es un organismo público de investigación cuyo objetivo final es conseguir, mediante la investigación, el desarrollo tecnológico, la formación y la transferencia, que las explotaciones agrarias y las empresas agroindustriales innoven continuamente y con ello alcanzar que la población activa agraria, y el resto de la población rural, obtenga una mayor rentabilidad económica y, como consecuencia, una mejor calidad de vida.Realizamos proyectos de ciencia ciudadana donde se estudia si el público asimila correctamente la información del etiquetado de los alimentos

# %%
projectsCS.iloc[top_indices]
# Out:
#                                           Project Name  \
# 138                                            GavaLab
# 18                   Banco de Imágenes del Mundo rural
# 312                                         Cicada.cat
# 48                               «CIUDADES que CUIDAN»
# 288  Centro de Investigación y Tecnología Agroalime...
#
#                                           Project Link  \
# 138  https://ciencia-ciudadana.es/proyecto-cc/gavalab/
# 18   https://ciencia-ciudadana.es/proyecto-cc/banco...
# 312  https://ciencia-ciudadana.es/proyecto-cc/cicad...
# 48   https://ciencia-ciudadana.es/proyecto-cc/ciuda...
# 288  https://ciencia-ciudadana.es/proyecto-cc/centr...
#
#                                          Project Scope  \
# 138  Biodiversidad, Ciencias Sociales, Informática ...
# 18   Animales, Biodiversidad, Biogeografía, Ciencia...
# 312            Biodiversidad, Ecología y Medioambiente
# 48   Biodiversidad, Biogeografía, Ciencias Política...
# 288  Animales, Biodiversidad, Biología, Ciencia de ...
#
#                                    Project Description  \
# 138                                                NaN
# 18   ¿Qué es el Banco de imágenes del mundo rural?\...
# 312  Cicada.cat avanza en el conocimiento y divulga...
# 48   Observatorio, para generar y facilitar informa...
# 288  Realizamos proyectos de ciencia ciudadana dond...
#
#                                           Project Goal  \
# 138  Thinkers Factory  basada en "el concepto de ga...
# 18   Preservar, conocer y difundir el patrimonio ru...
# 312  Ampliar el conocimiento sobre las cigarras (Ci...
# 48   Una ciudad que cuida ha de ser un referente do...
# 288  El CITA es un organismo público de investigaci...
#
#                               Project Full Description  \
# 138  Thinkers Factory  basada en "el concepto de ga...
# 18   Preservar, conocer y difundir el patrimonio ru...
# 312  Ampliar el conocimiento sobre las cigarras (Ci...
# 48   Una ciudad que cuida ha de ser un referente do...
# 288  El CITA es un organismo público de investigaci...
#
#                            Citizen Science Web Name  \
# 138  Observatorio de la Ciencia Ciudadana en España
# 18   Observatorio de la Ciencia Ciudadana en España
# 312  Observatorio de la Ciencia Ciudadana en España
# 48   Observatorio de la Ciencia Ciudadana en España
# 288  Observatorio de la Ciencia Ciudadana en España
#
#                       Citizen Science Web Link
# 138  https://ciencia-ciudadana.es/proyecto-cc/
# 18   https://ciencia-ciudadana.es/proyecto-cc/
# 312  https://ciencia-ciudadana.es/proyecto-cc/
# 48   https://ciencia-ciudadana.es/proyecto-cc/
# 288  https://ciencia-ciudadana.es/proyecto-cc/

# %%
top_idx_desc = []
for idx in top_indices:
  top_idx_desc.append(', '.join(build_terms(projectsCS_clean['Project Full Description'].iloc[idx])))

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

wordcloud = WordCloud(max_words=150, background_color="white").generate(', '.join(top_idx_desc))
plt.figure(figsize = (10,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
